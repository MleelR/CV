# %%
from ultralytics import YOLO
import cv2

import util
from sort.sort import *
from util import get_car, read_license_plate, write_csv


results = {}

mot_tracker = Sort()

# load models
coco_model = YOLO('yolov8m.pt')
license_plate_detector = YOLO('/Users/malik/Downloads/license_plate_detector.pt')

# load video
cap = cv2.VideoCapture('/Users/malik/Downloads/sample.mp4')

vehicles = [2, 3, 5, 7]

# read frames
frame_nmr = -1
ret = True
while ret:
    frame_nmr += 1
    ret, frame = cap.read()
    if ret:
        results[frame_nmr] = {}
        # detect vehicles
        detections = coco_model(frame)[0]
        detections_ = []
        for detection in detections.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = detection
            if int(class_id) in vehicles:
                detections_.append([x1, y1, x2, y2, score])

        # track vehicles
        track_ids = mot_tracker.update(np.asarray(detections_))

        # detect license plates
        license_plates = license_plate_detector(frame)[0]
        for license_plate in license_plates.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = license_plate

            # assign license plate to car
            xcar1, ycar1, xcar2, ycar2, car_id = get_car(license_plate, track_ids)

            if car_id != -1:

                # crop license plate
                license_plate_crop = frame[int(y1):int(y2), int(x1): int(x2), :]

                # process license plate
                license_plate_crop_gray = cv2.cvtColor(license_plate_crop, cv2.COLOR_BGR2GRAY)
                _, license_plate_crop_thresh = cv2.threshold(license_plate_crop_gray, 64, 255, cv2.THRESH_BINARY_INV)

                # read license plate number
                license_plate_text, license_plate_text_score = read_license_plate(license_plate_crop_thresh)

                if license_plate_text is not None:
                    results[frame_nmr][car_id] = {'car': {'bbox': [xcar1, ycar1, xcar2, ycar2]},
                                                  'license_plate': {'bbox': [x1, y1, x2, y2],
                                                                    'text': license_plate_text,
                                                                    'bbox_score': score,
                                                                    'text_score': license_plate_text_score}}

# write results
write_csv(results, './test.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ultralytics import YOLO
#       2 import cv2
#       4 import util
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 __version__ = '8.0.157'
# ----> 5 from ultralytics.hub import start
#       6 from ultralytics.models import RTDETR, SAM, YOLO
#       7 from ultralytics.models.fastsam import FastSAM
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/hub/__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 import requests
# ----> 5 from ultralytics.data.utils import HUBDatasetStats
#       6 from ultralytics.hub.auth import Auth
#       7 from ultralytics.hub.utils import HUB_API_ROOT, HUB_WEB_ROOT, PREFIX
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/data/__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .base import BaseDataset
#       4 from .build import build_dataloader, build_yolo_dataset, load_inference_source
#       5 from .dataset import ClassificationDataset, SemanticDataset, YOLODataset
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/data/base.py:18
#      15 from torch.utils.data import Dataset
#      16 from tqdm import tqdm
# ---> 18 from ultralytics.utils import DEFAULT_CFG, LOCAL_RANK, LOGGER, NUM_THREADS, TQDM_BAR_FORMAT
#      20 from .utils import HELP_URL, IMG_FORMATS
#      23 class BaseDataset(Dataset):
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/utils/__init__.py:857
#     854 from .patches import imread, imshow, imwrite
#     856 # torch.save = torch_save
# --> 857 if Path(inspect.stack()[0].filename).parent.parent.as_posix() in inspect.stack()[-1].filename:
#     858     cv2.imread, cv2.imwrite, cv2.imshow = imread, imwrite, imshow
#
# File ~/anaconda3/lib/python3.10/inspect.py:1681, in stack(context)
#    1679 def stack(context=1):
#    1680     """Return a list of records for the stack above the caller's frame."""
# -> 1681     return getouterframes(sys._getframe(1), context)
#
# File ~/anaconda3/lib/python3.10/inspect.py:1658, in getouterframes(frame, context)
#    1656 framelist = []
#    1657 while frame:
# -> 1658     frameinfo = (frame,) + getframeinfo(frame, context)
#    1659     framelist.append(FrameInfo(*frameinfo))
#    1660     frame = frame.f_back
#
# File ~/anaconda3/lib/python3.10/inspect.py:1632, in getframeinfo(frame, context)
#    1630 start = lineno - 1 - context//2
#    1631 try:
# -> 1632     lines, lnum = findsource(frame)
#    1633 except OSError:
#    1634     lines = index = None
#
# File ~/anaconda3/lib/python3.10/inspect.py:952, in findsource(object)
#     949     if not (file.startswith('<') and file.endswith('>')):
#     950         raise OSError('source code not available')
# --> 952 module = getmodule(object, file)
#     953 if module:
#     954     lines = linecache.getlines(file, module.__dict__)
#
# File ~/anaconda3/lib/python3.10/inspect.py:869, in getmodule(object, _filename)
#     866 # Update the filename to module name cache and check yet again
#     867 # Copy sys.modules in order to cope with changes while iterating
#     868 for modname, module in sys.modules.copy().items():
# --> 869     if ismodule(module) and hasattr(module, '__file__'):
#     870         f = module.__file__
#     871         if f == _filesbymodname.get(modname, None):
#     872             # Have already mapped this module, so skip it
#
# KeyboardInterrupt:
