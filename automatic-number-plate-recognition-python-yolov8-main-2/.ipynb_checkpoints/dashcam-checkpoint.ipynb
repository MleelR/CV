# %%
from ultralytics import YOLO
import cv2
import csv
import numpy as np
from sort.sort import *

# Your custom utility functions
from util import get_car, read_license_plate, write_csv

# Initialize variables
results = {}
mot_tracker = Sort()
coco_model = YOLO('yolov8m.pt')
license_plate_detector = YOLO('/Users/malik/Downloads/license_plate_detector.pt')

# Change this line to use the default camera
cap = cv2.VideoCapture(0)

# Initialize CSV writer
csv_file = open('output.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['frame_nmr', 'car_id', 'car_bbox', 'license_bbox', 'license_text', 'license_bbox_score', 'license_text_score'])

# Main loop
vehicles = [2, 3, 5, 7]
frame_nmr = -1
ret = True

while ret:
    frame_nmr += 1
    ret, frame = cap.read()
    if ret:
        results[frame_nmr] = {}
        detections = coco_model(frame)[0]
        detections_ = [[x1, y1, x2, y2, score] for x1, y1, x2, y2, score, class_id in detections.boxes.data.tolist() if int(class_id) in vehicles]
        track_ids = mot_tracker.update(np.array(detections_))
        license_plates = license_plate_detector(frame)[0]
        
        for license_plate in license_plates.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = license_plate
            xcar1, ycar1, xcar2, ycar2, car_id = get_car(license_plate, track_ids)
            if car_id != -1:
                license_plate_crop = frame[int(y1):int(y2), int(x1): int(x2), :]
                license_plate_text, license_plate_text_score = read_license_plate(license_plate_crop)
                
                if license_plate_text is not None:
                    results[frame_nmr][car_id] = {'car': {'bbox': [xcar1, ycar1, xcar2, ycar2]},
                                                  'license_plate': {'bbox': [x1, y1, x2, y2],
                                                                    'text': license_plate_text,
                                                                    'bbox_score': score,
                                                                    'text_score': license_plate_text_score}}
                    
                    # Write to CSV
                    csv_writer.writerow([frame_nmr, car_id, [xcar1, ycar1, xcar2, ycar2], [x1, y1, x2, y2], license_plate_text, score, license_plate_text_score])
                    
                    # Draw bounding boxes and text on the frame
                    cv2.rectangle(frame, (int(xcar1), int(ycar1)), (int(xcar2), int(ycar2)), (0, 255, 0), 2)
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 2)
                    cv2.putText(frame, license_plate_text, (int(x1), int(y1)-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

        # Show the frame in a window
        cv2.imshow('Real-time License Plate Recognition', frame)
        
        # Press 'q' to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# Release video and close CSV
cap.release()
csv_file.close()
cv2.destroyAllWindows()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
#
# 0: 384x640 1 person, 276.1ms
# Speed: 8.2ms preprocess, 276.1ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.8ms
# Speed: 2.3ms preprocess, 61.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 chair, 1 couch, 252.1ms
# Speed: 1.9ms preprocess, 252.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.5ms
# Speed: 1.7ms preprocess, 57.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 chair, 1 couch, 1 bed, 216.6ms
# Speed: 1.3ms preprocess, 216.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.3ms
# Speed: 1.5ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 chair, 1 couch, 218.8ms
# Speed: 1.5ms preprocess, 218.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.6ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 couch, 211.9ms
# Speed: 1.2ms preprocess, 211.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.9ms
# Speed: 1.5ms preprocess, 47.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 couch, 214.8ms
# Speed: 1.4ms preprocess, 214.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 1.4ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 211.0ms
# Speed: 1.2ms preprocess, 211.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.9ms
# Speed: 1.5ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 chair, 213.4ms
# Speed: 1.6ms preprocess, 213.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.5ms
# Speed: 1.7ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 chair, 216.4ms
# Speed: 1.5ms preprocess, 216.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.6ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 chair, 216.1ms
# Speed: 1.2ms preprocess, 216.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.4ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 chair, 216.8ms
# Speed: 1.2ms preprocess, 216.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 1.6ms preprocess, 48.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 220.1ms
# Speed: 1.3ms preprocess, 220.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 1.4ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 219.9ms
# Speed: 1.2ms preprocess, 219.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.0ms
# Speed: 1.5ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 214.8ms
# Speed: 1.5ms preprocess, 214.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.4ms preprocess, 47.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 220.5ms
# Speed: 1.2ms preprocess, 220.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 229.6ms
# Speed: 2.2ms preprocess, 229.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.0ms
# Speed: 1.7ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 couch, 213.2ms
# Speed: 1.3ms preprocess, 213.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.9ms
# Speed: 1.4ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 beds, 221.0ms
# Speed: 1.4ms preprocess, 221.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.7ms
# Speed: 1.4ms preprocess, 51.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 212.5ms
# Speed: 1.4ms preprocess, 212.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 bed, 218.6ms
# Speed: 1.2ms preprocess, 218.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.9ms
# Speed: 1.5ms preprocess, 47.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 bed, 210.9ms
# Speed: 1.3ms preprocess, 210.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.3ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 209.8ms
# Speed: 1.4ms preprocess, 209.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.3ms
# Speed: 1.5ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 214.9ms
# Speed: 1.3ms preprocess, 214.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 1.4ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 211.5ms
# Speed: 1.4ms preprocess, 211.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 208.2ms
# Speed: 1.7ms preprocess, 208.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 221.5ms
# Speed: 1.3ms preprocess, 221.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.5ms
# Speed: 1.6ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 209.7ms
# Speed: 1.4ms preprocess, 209.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 219.0ms
# Speed: 1.4ms preprocess, 219.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.3ms
# Speed: 1.4ms preprocess, 45.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 204.5ms
# Speed: 1.3ms preprocess, 204.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.7ms
# Speed: 1.4ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 205.9ms
# Speed: 1.2ms preprocess, 205.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.2ms
# Speed: 1.7ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 211.8ms
# Speed: 1.2ms preprocess, 211.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 209.3ms
# Speed: 1.2ms preprocess, 209.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.3ms
# Speed: 1.8ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 219.4ms
# Speed: 1.3ms preprocess, 219.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 202.7ms
# Speed: 1.3ms preprocess, 202.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 1.6ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 211.5ms
# Speed: 1.4ms preprocess, 211.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 206.6ms
# Speed: 1.2ms preprocess, 206.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 202.3ms
# Speed: 1.2ms preprocess, 202.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 208.1ms
# Speed: 1.2ms preprocess, 208.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 207.0ms
# Speed: 1.4ms preprocess, 207.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.6ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 223.9ms
# Speed: 1.1ms preprocess, 223.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.6ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 216.2ms
# Speed: 1.2ms preprocess, 216.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.6ms
# Speed: 1.6ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 209.8ms
# Speed: 1.5ms preprocess, 209.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.4ms
# Speed: 1.3ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 209.7ms
# Speed: 1.6ms preprocess, 209.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.1ms
# Speed: 1.4ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 205.5ms
# Speed: 1.3ms preprocess, 205.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 218.4ms
# Speed: 1.3ms preprocess, 218.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.6ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 215.9ms
# Speed: 1.2ms preprocess, 215.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.1ms
# Speed: 1.5ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 221.6ms
# Speed: 1.1ms preprocess, 221.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 1.8ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 213.0ms
# Speed: 1.3ms preprocess, 213.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.3ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 213.6ms
# Speed: 1.3ms preprocess, 213.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.4ms
# Speed: 1.5ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 212.5ms
# Speed: 1.3ms preprocess, 212.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.5ms
# Speed: 1.3ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 214.1ms
# Speed: 1.5ms preprocess, 214.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 1.3ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 255.3ms
# Speed: 1.2ms preprocess, 255.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.9ms
# Speed: 1.8ms preprocess, 47.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 217.7ms
# Speed: 1.3ms preprocess, 217.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.2ms
# Speed: 1.6ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 224.3ms
# Speed: 1.4ms preprocess, 224.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.2ms
# Speed: 1.6ms preprocess, 48.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 232.1ms
# Speed: 1.2ms preprocess, 232.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.8ms
# Speed: 1.4ms preprocess, 47.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 224.2ms
# Speed: 1.3ms preprocess, 224.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.6ms preprocess, 47.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 34
#      32 if ret:
#      33     results[frame_nmr] = {}
# ---> 34     detections = coco_model(frame)[0]
#      35     detections_ = [[x1, y1, x2, y2, score] for x1, y1, x2, y2, score, class_id in detections.boxes.data.tolist() if int(class_id) in vehicles]
#      36     track_ids = mot_tracker.update(np.array(detections_))
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/engine/model.py:98, in Model.__call__(self, source, stream, **kwargs)
#      96 def __call__(self, source=None, stream=False, **kwargs):
#      97     """Calls the 'predict' function with given arguments to perform object detection."""
# ---> 98     return self.predict(source, stream, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/engine/model.py:246, in Model.predict(self, source, stream, predictor, **kwargs)
#     244 if len and hasattr(self.predictor, 'set_prompts'):
#     245     self.predictor.set_prompts(prompts)
# --> 246 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/engine/predictor.py:197, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     195     return self.stream_inference(source, model, *args, **kwargs)
#     196 else:
# --> 197     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/engine/predictor.py:253, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     251 # Inference
#     252 with profilers[1]:
# --> 253     preds = self.inference(im, *args, **kwargs)
#     255 # Postprocess
#     256 with profilers[2]:
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/engine/predictor.py:138, in BasePredictor.inference(self, im, *args, **kwargs)
#     135 def inference(self, im, *args, **kwargs):
#     136     visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     137                                mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 138     return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:334, in AutoBackend.forward(self, im, augment, visualize)
#     331     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     333 if self.pt or self.nn_module:  # PyTorch
# --> 334     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     335 elif self.jit:  # TorchScript
#     336     y = self.model(im)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/nn/tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/nn/tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File ~/anaconda3/lib/python3.10/site-packages/ultralytics/nn/tasks.py:83, in BaseModel._predict_once(self, x, profile, visualize)
#      81     self._profile_one_layer(m, x, dt)
#      82 x = m(x)  # run
# ---> 83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#      85     feature_visualization(x, m.type, m.i, save_dir=visualize)
#
# KeyboardInterrupt:
