# %%
from ultralytics import YOLO
import cv2

import util
from sort.sort import *
from util import get_car, read_license_plate, write_csv


results = {}

mot_tracker = Sort()

# load models
coco_model = YOLO('yolov8m.pt')
license_plate_detector = YOLO('/Users/malik/Downloads/license_plate_detector.pt')

# load video
cap = cv2.VideoCapture('/Users/malik/Downloads/IMG_7066.mp4')

vehicles = [2, 3, 5, 7]

# read frames
frame_nmr = -1
ret = True
while ret:
    frame_nmr += 1
    ret, frame = cap.read()
    if ret:
        results[frame_nmr] = {}
        # detect vehicles
        detections = coco_model(frame)[0]
        detections_ = []
        for detection in detections.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = detection
            if int(class_id) in vehicles:
                detections_.append([x1, y1, x2, y2, score])

        # track vehicles
        track_ids = mot_tracker.update(np.asarray(detections_))

        # detect license plates
        license_plates = license_plate_detector(frame)[0]
        for license_plate in license_plates.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = license_plate

            # assign license plate to car
            xcar1, ycar1, xcar2, ycar2, car_id = get_car(license_plate, track_ids)

            if car_id != -1:

                # crop license plate
                license_plate_crop = frame[int(y1):int(y2), int(x1): int(x2), :]

                # process license plate
                license_plate_crop_gray = cv2.cvtColor(license_plate_crop, cv2.COLOR_BGR2GRAY)
                _, license_plate_crop_thresh = cv2.threshold(license_plate_crop_gray, 64, 255, cv2.THRESH_BINARY_INV)

                # read license plate number
                license_plate_text, license_plate_text_score = read_license_plate(license_plate_crop_thresh)

                if license_plate_text is not None:
                    results[frame_nmr][car_id] = {'car': {'bbox': [xcar1, ycar1, xcar2, ycar2]},
                                                  'license_plate': {'bbox': [x1, y1, x2, y2],
                                                                    'text': license_plate_text,
                                                                    'bbox_score': score,
                                                                    'text_score': license_plate_text_score}}

# write results
write_csv(results, './test.csv')

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: ultralytics==8.0.114 in /Users/malik/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (8.0.114)
# Collecting pandas==2.0.2
#   Using cached pandas-2.0.2-cp310-cp310-macosx_10_9_x86_64.whl (11.8 MB)
# Collecting opencv-python==4.7.0.72
#   Downloading opencv_python-4.7.0.72-cp37-abi3-macosx_10_16_x86_64.whl (53.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 MB 760.6 kB/s eta 0:00:0000:0100:02
# Requirement already satisfied: numpy==1.24.3 in /Users/malik/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.24.3)
# Collecting scipy==1.10.1
#   Downloading scipy-1.10.1-cp310-cp310-macosx_10_9_x86_64.whl (35.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.1/35.1 MB 2.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: easyocr==1.7.0 in /Users/malik/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.7.0)
# Requirement already satisfied: filterpy==1.4.5 in /Users/malik/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.4.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/malik/anaconda3/lib/python3.10/site-packages (from ultralytics==8.0.114->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: psutil in /Users/malik/anaconda3/lib/python3.10/site-packages (from ultralytics==8.0.114->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: torch>=1.7.0 in /Users/malik/anaconda3/lib/python3.10/site-packages (from ultralytics==8.0.114->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: torchvision>=0.8.1 in /Users/malik/anaconda3/lib/python3.10/site-packages (from ultralytics==8.0.114->-r requirements.txt (line 1)) (0.15.2)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/malik/anaconda3/lib/python3.10/site-packages (from ultralytics==8.0.114->-r requirements.txt (line 1)) (0.12.2)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/malik/anaconda3/lib/python3.10/site-packages (from ultralytics==8.0.114->-r requirements.txt (line 1)) (9.3.0)
# Requirement already satisfied: requests>=2.23.0 in /Users/malik/anaconda3/lib/python3.10/site-packages (from ultralytics==8.0.114->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/malik/anaconda3/lib/python3.10/site-packages (from ultralytics==8.0.114->-r requirements.txt (line 1)) (4.66.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /Users/malik/anaconda3/lib/python3.10/site-packages (from ultralytics==8.0.114->-r requirements.txt (line 1)) (3.7.2)
# Collecting python-dateutil>=2.8.2
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/malik/anaconda3/lib/python3.10/site-packages (from pandas==2.0.2->-r requirements.txt (line 2)) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/malik/anaconda3/lib/python3.10/site-packages (from pandas==2.0.2->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: ninja in /Users/malik/anaconda3/lib/python3.10/site-packages (from easyocr==1.7.0->-r requirements.txt (line 6)) (1.11.1)
# Requirement already satisfied: opencv-python-headless in /Users/malik/anaconda3/lib/python3.10/site-packages (from easyocr==1.7.0->-r requirements.txt (line 6)) (4.8.0.76)
# Requirement already satisfied: pyclipper in /Users/malik/anaconda3/lib/python3.10/site-packages (from easyocr==1.7.0->-r requirements.txt (line 6)) (1.3.0.post4)
# Requirement already satisfied: scikit-image in /Users/malik/anaconda3/lib/python3.10/site-packages (from easyocr==1.7.0->-r requirements.txt (line 6)) (0.19.3)
# Requirement already satisfied: Shapely in /Users/malik/anaconda3/lib/python3.10/site-packages (from easyocr==1.7.0->-r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: python-bidi in /Users/malik/anaconda3/lib/python3.10/site-packages (from easyocr==1.7.0->-r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/malik/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.114->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/malik/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.114->-r requirements.txt (line 1)) (4.25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/malik/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.114->-r requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/malik/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.114->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/malik/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.114->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/malik/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.114->-r requirements.txt (line 1)) (22.0)
# Requirement already satisfied: six>=1.5 in /Users/malik/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.0.2->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/malik/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in /Users/malik/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/malik/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/malik/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: jinja2 in /Users/malik/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: typing-extensions in /Users/malik/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (4.7.1)
# Requirement already satisfied: sympy in /Users/malik/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: networkx in /Users/malik/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (2.8.4)
# Requirement already satisfied: filelock in /Users/malik/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/malik/anaconda3/lib/python3.10/site-packages (from scikit-image->easyocr==1.7.0->-r requirements.txt (line 6)) (2021.7.2)
# Requirement already satisfied: imageio>=2.4.1 in /Users/malik/anaconda3/lib/python3.10/site-packages (from scikit-image->easyocr==1.7.0->-r requirements.txt (line 6)) (2.26.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/malik/anaconda3/lib/python3.10/site-packages (from scikit-image->easyocr==1.7.0->-r requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/malik/anaconda3/lib/python3.10/site-packages (from jinja2->torch>=1.7.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/malik/anaconda3/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch>=1.7.0->ultralytics==8.0.114->-r requirements.txt (line 1)) (1.2.1)
# Installing collected packages: scipy, python-dateutil, opencv-python, pandas
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.1
#     Uninstalling scipy-1.11.1:
#       Successfully uninstalled scipy-1.11.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# supervision 0.13.0 requires pillow<10.0.0,>=9.4.0, but you have pillow 9.3.0 which is incompatible.
# label-studio 1.8.2 requires python-dateutil==2.8.1, but you have python-dateutil 2.8.2 which is incompatible.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.41 requires PyYAML==6.0, but you have pyyaml 6.0.1 which is incompatible.
# conda-repo-cli 1.0.41 requires requests==2.28.1, but you have requests 2.31.0 which is incompatible.
# Successfully installed opencv-python-4.7.0.72 pandas-2.0.2 python-dateutil-2.8.2 scipy-1.10.1
